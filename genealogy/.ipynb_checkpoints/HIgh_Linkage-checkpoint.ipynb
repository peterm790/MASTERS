# %%
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import math
import glob
import pickle
import statistics
import scipy.stats as stats
from sklearn.neighbors import KernelDensity
import dask
import seaborn as sns
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
def get_files():
    models = glob.glob("/terra/data/cmip5/global/historical/*")
    avail={}
    for model in models:
        zg = glob.glob(str(model)+"/r1i1p1/day/2deg/zg*")
        try:
            test = zg[0]
            avail[model.split('/')[-1]] = zg
        except:
             pass
    return avail

# %%
files = get_files()
files['NOAA'] = glob.glob("/home/pmarsh/NOAA_2deg/NOAA_zg/*.nc") #need 2degs!
files['ERA5'] = glob.glob("/home/pmarsh/NOAA_2deg/ERA5_zg/*.nc")
files.pop('MIROC-ESM')
# Out:
# ['/terra/data/cmip5/global/historical/MIROC-ESM/r1i1p1/day/2deg/zg_day_MIROC-ESM_historical_r1i1p1_19500101-20051231.nc']

# %%
def contourise(x):
    x = x.fillna(0)
    x = x.where((x>=limit))
    x = x/x
    return x

# %%
results={}
for model in ['NOAA','GFDL-CM3']:
    print(model)
    x = xr.open_mfdataset(files[model])
    if model == 'NOAA':
        x = x.rename({'hgt':'zg'})
        x = x.rename({'level':'plev'})
        x = x.sel(plev=850)
        x = x.sel(time=slice('1950','2005'))
    elif model == 'ERA5':
        x = x.rename({'level':'plev'})
        x = x.sel(plev=850)
        x = x.sel(time=slice('1979','2005'))
    else:
        x = x.sel(plev=85000)
        x = x.sel(time=slice('1950','2005'))
        x = x.load()
    x = x.sel(lat=slice(-60,0))
    x = x[['zg']]
    x = x.assign_coords(lon=(((x.lon + 180) % 360) - 180))
    with dask.config.set(**{'array.slicing.split_large_chunks': True}):
        x = x.sortby(x.lon)
    x = x.sel(lon=slice(-50,20))
    x = x.resample(time="QS-DEC").mean(dim="time",skipna=True)
    x = x.load()
    limit = np.nanquantile(x.zg.values,0.9)
    results[model]={}
    for seas in ['DJF','MAM','JJA','SON']:
        mean_seas = x.where(x.time.dt.season==str(seas)).dropna(dim='time')
        mean_seas = contourise(mean_seas).zg.fillna(0).mean(dim='time')
        results[model][seas] = mean_seas.fillna(0)
    x.close()
# Out:
# NOAA
# GFDL-CM3

# %%
scores=[]
for index in results:
    reference = index
    for index in results:
        MAE=[]
        for season in ['DJF','MAM','JJA','SON']:
            ref = results[reference][season]
            x = results[index][season]
            for i in ref.lat.values:
                for j in ref.lon.values:
                    MAE.append(float(np.abs(ref.sel(lat=i).sel(lon=j) - x.sel(lat=i).sel(lon=j)).values))
        scores.append([reference,index,np.mean(MAE)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: -24.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-27556490b46a> in <module>
#       9             for i in ref.lat.values:
#      10                 for j in ref.lon.values:
# ---> 11                     MAE.append(float(np.abs(ref.sel(lat=i).sel(lon=j) - x.sel(lat=i).sel(lon=j)).values))
#      12         scores.append([reference,index,np.mean(MAE)])
#
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/xarray/core/dataarray.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1252         Dimensions without coordinates: points
#    1253         """
# -> 1254         ds = self._to_temp_dataset().sel(
#    1255             indexers=indexers,
#    1256             drop=drop,
#
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2228         """
#    2229         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2230         pos_indexers, new_indexes = remap_label_indexers(
#    2231             self, indexers=indexers, method=method, tolerance=tolerance
#    2232         )
#
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/xarray/core/coordinates.py in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     414     }
#     415
# --> 416     pos_indexers, new_indexes = indexing.remap_label_indexers(
#     417         obj, v_indexers, method=method, tolerance=tolerance
#     418     )
#
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/xarray/core/indexing.py in remap_label_indexers(data_obj, indexers, method, tolerance)
#     268             coords_dtype = data_obj.coords[dim].dtype
#     269             label = maybe_cast_to_coords_dtype(label, coords_dtype)
# --> 270             idxr, new_idx = convert_label_indexer(index, label, dim, method, tolerance)
#     271             pos_indexers[dim] = idxr
#     272             if new_idx is not None:
#
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/xarray/core/indexing.py in convert_label_indexer(index, label, index_name, method, tolerance)
#     189                 indexer = index.get_loc(label_value)
#     190             else:
# --> 191                 indexer = index.get_loc(label_value, method=method, tolerance=tolerance)
#     192         elif label.dtype.kind == "b":
#     193             indexer = label
#
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/pandas/core/indexes/numeric.py in get_loc(self, key, method, tolerance)
#     393             return nan_idxs
#     394
# --> 395         return super().get_loc(key, method=method, tolerance=tolerance)
#     396
#     397     # ----------------------------------------------------------------
#
# /share/apps/anaconda3/envs/dask/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: -24.0

# %%
models = list(results.keys())

# %%
df = pd.DataFrame(models,columns = ['models'])
start = 0
end = len(models)
for index in models:
    df[index] = np.array(scores[start:end])[:,-1].astype(float)
    start = start + len(models)
    end = end + len(models)

# %%
df = df.set_index('models')

# %%
df.to_csv('High_2D_Linkage.csv')

# %%
df = df.dropna(0,how='all').dropna(1,how='all')

# %%
xr.open_mfdataset(files['NOAA'])
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 18, level: 2, lon: 61, time: 42368)
# Coordinates:
#   * time     (time) datetime64[ns] 1900-01-01 1900-01-02 ... 2015-12-31
#   * lon      (lon) float64 -60.0 -58.0 -56.0 -54.0 -52.0 ... 54.0 56.0 58.0 60.0
#   * lat      (lat) float64 -60.0 -58.0 -56.0 -54.0 ... -32.0 -30.0 -28.0 -26.0
#   * level    (level) float32 850.0 700.0
# Data variables:
#     hgt      (time, level, lat, lon) float32 dask.array<chunksize=(42368, 2, 18, 61), meta=np.ndarray>
# Attributes: (12/26)
#     CDI:                       Climate Data Interface version 1.9.7.1 (http:/...
#     history:                   Thu Jan 14 18:57:46 2021: cdo -sellonlatbox,-6...
#     source:                    20CRv3si 2018, Ensemble Kalman Filter, ocean (...
#     institution:               NOAA Physical Sciences Laboratory & CU/CIRES \...
#     Conventions:               CF-1.2
#     title:                     mean Daily NOAA/CIRES/DOE 20th Century Reanaly...
#     ...                        ...
#     citation1:                 Slivinski, L. C, G. P. Compo, J. S. Whitaker, ...
#     References:                https://www.psl.noaa.gov/data/gridded/data.20t...
#     creator_name:              NOAA/PSL
#     contact:                   psl.data@noaa.gov
#     citation:                  Compo,G.P. <https://www.psl.noaa.gov/people/gi...
#     CDO:                       Climate Data Operators version 1.9.7.1 (http:/...
