# %%
import numpy as np
import pandas as pd
import xarray as xr
import math
import dask
import glob
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
files = glob.glob("../FRONT/FRONT_FILES/native/3-hourly/*.nc")

models = []
for file in files:
    models.append(file.split('/')[-1].split('_')[0])

# %%
NOAA_2deg = xr.open_dataset('../FRONT/FRONT_FILES/2deg/3-hourly/NOAA_front_6hr.nc')
new_lat = NOAA_2deg.latitude.values
new_lon = NOAA_2deg.longitude.values

# %%
dic = {}
for model in models:
    print(model)
    dic[model] = xr.open_dataset('../FRONT/FRONT_FILES/native/3-hourly/'+str(model)+'_front_native.nc')
    dic[model] = dic[model].rename({'longitude':'lon'})
    dic[model] = dic[model].rename({'latitude':'lat'})
    zero = dic[model].where(dic[model].time.dt.hour == 0).dropna(dim='time',how='all')
    twelve = dic[model].where(dic[model].time.dt.hour == 12).dropna(dim='time',how='all')
    dic[model] = xr.DataArray(np.concatenate([zero.front.values,twelve.front.values]),dims=("time","lat", "lon"), coords={"time":np.concatenate([zero.time.values,twelve.time.values]),"lon":zero.lon.values ,"lat": zero.lat.values})
    dic[model] = dic[model].sortby(dic[model].time)
    dic[model] = dic[model].fillna(0)
    dic[model] = dic[model].sortby('lat')
    dic[model] = dic[model].sortby('lon')
    dic[model] = dic[model].sel(time = slice('1981-03-01','2005-12-30'))  #change from 1950/1981 here
    dic[model] = dic[model].groupby(dic[model].time.dt.season).mean(dim='time',skipna=True)
    dic[model] = dic[model].interp(lat=new_lat, lon=new_lon,method='linear')
    dic[model] = dic[model].fillna(0)
    dic[model] = dic[model].sel(lat = slice(-60,-25))
    dic[model] = dic[model].sel(lon = slice(-30,10))
    dic[model] = dic[model]/(np.max(dic[model].values))
# Out:
# ERA5
# GFDL-CM3
# CNRM-CM5
# GFDL-ESM2M
# MIROC5
# GFDL-ESM2G
# bcc-csm1-1
# MIROC-ESM
# MIROC-ESM-CHEM
# MRI-ESM1
# IPSL-CM5A-MR
# NOAA
# MRI-CGCM3
# BNU-ESM
# ACCESS1-3
# ACCESS1-0
# bcc-csm1-1-m
# IPSL-CM5A-LR
# MIROC4h

# %%
dic_native = dic
dic_native.pop('MIROC4h')
# Out:
# <xarray.DataArray (season: 4, lat: 18, lon: 21)>
# array([[[0.41234112, 0.38401682, 0.39989392, ..., 0.33677317,
#          0.34104367, 0.30435665],
#         [0.45675851, 0.46818272, 0.51008226, ..., 0.38723887,
#          0.40538553, 0.43811632],
#         [0.54132364, 0.58347568, 0.60514104, ..., 0.48418613,
#          0.47152723, 0.52779202],
#         ...,
#         [0.2304128 , 0.23756887, 0.21884316, ..., 0.09203896,
#          0.06808432, 0.03193903],
#         [0.17499717, 0.16350297, 0.16282954, ..., 0.03671094,
#          0.02074774, 0.01344092],
#         [0.10422957, 0.08696358, 0.100257  , ..., 0.01024246,
#          0.00301962, 0.00203909]],
#
#        [[0.50514239, 0.47336996, 0.46861694, ..., 0.44068794,
#          0.44543764, 0.4966371 ],
#         [0.51570212, 0.54551887, 0.52401427, ..., 0.51251291,
#          0.54026827, 0.59420646],
#         [0.64123211, 0.60067793, 0.64554071, ..., 0.57957246,
#          0.59686827, 0.65049151],
# ...
#         [0.35811524, 0.34367985, 0.33022829, ..., 0.18644233,
#          0.17227664, 0.14710149],
#         [0.30817151, 0.2879901 , 0.25530435, ..., 0.1304989 ,
#          0.08493   , 0.07320684],
#         [0.2285297 , 0.1654499 , 0.17623947, ..., 0.05386819,
#          0.04066904, 0.0485671 ]],
#
#        [[0.5543127 , 0.51707943, 0.57599332, ..., 0.42789263,
#          0.44834163, 0.45344161],
#         [0.58273587, 0.58015534, 0.57447587, ..., 0.51211606,
#          0.56101774, 0.49994327],
#         [0.62300961, 0.62630866, 0.61982291, ..., 0.51403926,
#          0.59599538, 0.57980276],
#         ...,
#         [0.37190335, 0.39018972, 0.43218791, ..., 0.28988885,
#          0.24671157, 0.20117977],
#         [0.32923567, 0.38759705, 0.26339294, ..., 0.18060804,
#          0.12823566, 0.12986293],
#         [0.29335248, 0.26816298, 0.2813695 , ..., 0.09586225,
#          0.08240335, 0.06458226]]])
# Coordinates:
#   * season   (season) object 'DJF' 'JJA' 'MAM' 'SON'
#   * lat      (lat) float64 -60.0 -58.0 -56.0 -54.0 ... -32.0 -30.0 -28.0 -26.0
#   * lon      (lon) float64 -30.0 -28.0 -26.0 -24.0 -22.0 ... 4.0 6.0 8.0 10.0

# %%
scores=[]
for index in dic_native:
    print(index)
    reference = index
    for index in dic_native:
        MAE=[]
        for seas in ['DJF','MAM','JJA','SON']:
            ref = dic_native[reference].sel(season = seas)
            x = dic_native[index].sel(season = seas)
            for i in ref.lat.values:
                for j in ref.lon.values:
                    MAE.append(float(np.abs(ref.sel(lat=i).sel(lon=j).values - x.sel(lat=i).sel(lon=j)).values))
        scores.append([reference,index,np.mean(MAE)])

models = list(dic_native.keys())
# Out:
# ERA5
# GFDL-CM3
# CNRM-CM5
# GFDL-ESM2M
# MIROC5
# GFDL-ESM2G
# bcc-csm1-1
# MIROC-ESM
# MIROC-ESM-CHEM
# MRI-ESM1
# IPSL-CM5A-MR
# NOAA
# MRI-CGCM3
# BNU-ESM
# ACCESS1-3
# ACCESS1-0
# bcc-csm1-1-m
# IPSL-CM5A-LR

# %%
df = pd.DataFrame(models,columns = ['models'])
start = 0
end = len(models)
for index in models:
    df[index] = np.array(scores[start:end])[:,-1].astype(float)
    start = start + len(models)
    end = end + len(models)

# %%
df = df.set_index('models')

df.to_csv('Front_Linkage.csv')

# %%
df
# Out:
#                     ERA5  GFDL-CM3  CNRM-CM5  GFDL-ESM2M    MIROC5  \
# models
# ERA5            0.000000  0.063552  0.116029    0.072634  0.072988
# GFDL-CM3        0.063552  0.000000  0.133535    0.067483  0.073946
# CNRM-CM5        0.116029  0.133535  0.000000    0.099408  0.077143
# GFDL-ESM2M      0.072634  0.067483  0.099408    0.000000  0.059495
# MIROC5          0.072988  0.073946  0.077143    0.059495  0.000000
# GFDL-ESM2G      0.073485  0.058242  0.114725    0.037486  0.065540
# bcc-csm1-1      0.081427  0.111757  0.074685    0.091161  0.076981
# MIROC-ESM       0.068635  0.087165  0.089784    0.083146  0.070952
# MIROC-ESM-CHEM  0.074380  0.095519  0.086205    0.095424  0.075386
# MRI-ESM1        0.072891  0.085911  0.147909    0.094679  0.106952
# IPSL-CM5A-MR    0.107186  0.108137  0.093179    0.102179  0.097230
# NOAA            0.052787  0.064298  0.111765    0.074645  0.068893
# MRI-CGCM3       0.076156  0.090368  0.149815    0.095745  0.106124
# BNU-ESM         0.096710  0.114343  0.077742    0.093566  0.079860
# ACCESS1-3       0.061758  0.065334  0.148064    0.069995  0.093320
# ACCESS1-0       0.050973  0.047907  0.133273    0.072048  0.078870
# bcc-csm1-1-m    0.057150  0.073671  0.121399    0.068641  0.084670
# IPSL-CM5A-LR    0.136992  0.144418  0.088487    0.127284  0.109007
#
#                 GFDL-ESM2G  bcc-csm1-1  MIROC-ESM  MIROC-ESM-CHEM  MRI-ESM1  \
# models
# ERA5              0.073485    0.081427   0.068635        0.074380  0.072891
# GFDL-CM3          0.058242    0.111757   0.087165        0.095519  0.085911
# CNRM-CM5          0.114725    0.074685   0.089784        0.086205  0.147909
# GFDL-ESM2M        0.037486    0.091161   0.083146        0.095424  0.094679
# MIROC5            0.065540    0.076981   0.070952        0.075386  0.106952
# GFDL-ESM2G        0.000000    0.102712   0.093809        0.103792  0.098921
# bcc-csm1-1        0.102712    0.000000   0.068759        0.060967  0.102444
# MIROC-ESM         0.093809    0.068759   0.000000        0.036895  0.089818
# MIROC-ESM-CHEM    0.103792    0.060967   0.036895        0.000000  0.097227
# MRI-ESM1          0.098921    0.102444   0.089818        0.097227  0.000000
# IPSL-CM5A-MR      0.106010    0.073255   0.075928        0.082323  0.116504
# NOAA              0.077605    0.074824   0.063881        0.068995  0.076357
# MRI-CGCM3         0.099795    0.105500   0.092351        0.098691  0.036142
# BNU-ESM           0.108078    0.086327   0.065984        0.072207  0.132513
